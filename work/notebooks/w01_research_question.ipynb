# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gitWithPrince272/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane: Google Search Ranking & Discoverability
#
# I chose the Google Search Ranking & Discoverability lane because it matches my interest in Machine Learning and data analysis. I want to understand which page characteristics are related to better search performance and use data to support ranking decisions. This lane will help me learn how to analyze real-world search data instead of making assumptions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Decision, Action, Cost of Wrong Call
#
# **Decision:** Which web pages should be improved first to increase search visibility?
#
# **Who acts on it?** SEO specialists, digital marketers, and website content managers.
#
# **Action:** Prioritize the selected pages for SEO improvements, content updates, and technical optimization.
#
# **Cost of a wrong recommendation:** If the wrong pages are selected, time and effort will be wasted, important pages may continue losing traffic, and the website may receive fewer visitors from search engines.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# - Total pages analyzed: 200
# - Average search position: 18.4
# - Average click-through rate (CTR): 3.2%
#
# These numbers provide an initial view of the website's search performance and help identify pages that may need optimization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words
#
# This work provides decision support based on observed data and patterns. It can help identify which pages may benefit from SEO improvements. It does not prove that these changes will definitely increase rankings or traffic, and it does not establish cause and effect.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane: Google Search Ranking & Discoverability
#
# I chose the Google Search Ranking & Discoverability lane because it matches my interest in Machine Learning and data analysis. I want to understand which page characteristics are related to better search performance and use data to support ranking decisions. This lane will help me learn how to analyze real-world search data instead of making assumptions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
